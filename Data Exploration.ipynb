# %%
import pandas as pd

# %%
data=pd.read_csv('vehicles.csv')

# %%
data.shape
# Out:
# (435849, 25)

# %%
data.head(10)
# Out:
#            id                                                url  \
# 0  7119256118  https://mohave.craigslist.org/ctd/d/lake-havas...
# 1  7120880186  https://oregoncoast.craigslist.org/cto/d/warre...
# 2  7115048251  https://greenville.craigslist.org/cto/d/sparta...
# 3  7119250502  https://mohave.craigslist.org/cto/d/lake-havas...
# 4  7120433904  https://maine.craigslist.org/ctd/d/searsport-t...
# 5  7120432569  https://maine.craigslist.org/ctd/d/bad-credit-...
# 6  7120431378  https://maine.craigslist.org/ctd/d/salem-nh-ma...
# 7  7120430837  https://maine.craigslist.org/cto/d/gardiner-20...
# 8  7120857037  https://oregoncoast.craigslist.org/ctd/d/portl...
# 9  7120844862  https://oregoncoast.craigslist.org/ctd/d/portl...
#
#                  region                          region_url  price    year  \
# 0         mohave county       https://mohave.craigslist.org   3495  2012.0
# 1          oregon coast  https://oregoncoast.craigslist.org  13750  2014.0
# ...

# %%
data.tail()
# Out:
#                 id                                                url  \
# 435844  7119262300  https://mohave.craigslist.org/cto/d/hualapai-2...
# 435845  7112219717  https://rapidcity.craigslist.org/cto/d/rapid-c...
# 435846  7120896708  https://oregoncoast.craigslist.org/cto/d/corne...
# 435847  7120885819  https://oregoncoast.craigslist.org/ctd/d/portl...
# 435848  7112215161  https://rapidcity.craigslist.org/ctd/d/rapid-c...
#
#                       region                          region_url  price  \
# 435844         mohave county       https://mohave.craigslist.org   2500
# 435845  rapid city / west SD    https://rapidcity.craigslist.org   2700
# 435846          oregon coast  https://oregoncoast.craigslist.org   2450
# 435847          oregon coast  https://oregoncoast.craigslist.org   8995
# 435848  rapid city / west SD    https://rapidcity.craigslist.org   6577
#
#           year manufacturer          model condition    cylinders  ... drive  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435849 entries, 0 to 435848
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            435849 non-null  int64
#  1   url           435849 non-null  object
#  2   region        435849 non-null  object
#  3   region_url    435849 non-null  object
#  4   price         435849 non-null  int64
#  5   year          434732 non-null  float64
#  6   manufacturer  415102 non-null  object
#  7   model         429650 non-null  object
#  8   condition     249043 non-null  object
#  9   cylinders     269465 non-null  object
#  10  fuel          432858 non-null  object
#  11  odometer      360701 non-null  float64
#  12  title_status  434043 non-null  object
#  13  transmission  433703 non-null  object
#  14  vin           239197 non-null  object
#  15  drive         313838 non-null  object
#  16  size          139888 non-null  object
# ...

# %%
data.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.358490e+05  4.358490e+05  434732.000000  3.607010e+05     0.0
# mean   7.115954e+09  1.349127e+05    2009.866460  9.897590e+04     NaN
# std    4.590854e+06  1.690857e+07       9.312503  1.134990e+05     NaN
# min    7.096577e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.112450e+09  4.900000e+03    2007.000000  4.733300e+04     NaN
# 50%    7.117092e+09  9.995000e+03    2012.000000  9.118800e+04     NaN
# 75%    7.120090e+09  1.798900e+04    2015.000000  1.347360e+05     NaN
# max    7.121608e+09  3.647257e+09    2021.000000  1.000000e+07     NaN
#
#                  lat           long
# count  427614.000000  427614.000000
# mean       38.404163     -94.961170
# std         6.036915      18.058561
# min       -83.197100    -177.012000
# 25%        34.225700    -111.731000
# 50%        38.934800     -89.676700
# 75%        42.484500     -81.397300
# ...

# %%
data.dtypes
# Out:
# id                int64
# url              object
# region           object
# region_url       object
# price             int64
# year            float64
# manufacturer     object
# model            object
# condition        object
# cylinders        object
# fuel             object
# odometer        float64
# title_status     object
# transmission     object
# vin              object
# drive            object
# size             object
# type             object
# paint_color      object
# image_url        object
# description      object
# county          float64
# state            object
# lat             float64
# long            float64
# dtype: object

# %%
data.isnull()
# Out:
#            id    url  region  region_url  price   year  manufacturer  model  \
# 0       False  False   False       False  False  False         False  False
# 1       False  False   False       False  False  False         False  False
# 2       False  False   False       False  False  False         False  False
# 3       False  False   False       False  False  False         False  False
# 4       False  False   False       False  False  False          True  False
# ...       ...    ...     ...         ...    ...    ...           ...    ...
# 435844  False  False   False       False  False  False         False  False
# 435845  False  False   False       False  False  False         False  False
# 435846  False  False   False       False  False  False         False  False
# 435847  False  False   False       False  False  False         False  False
# 435848  False  False   False       False  False  False         False  False
#
# ...

# %%
data.isnull().any()
# Out:
# id              False
# url             False
# region          False
# region_url      False
# price           False
# year             True
# manufacturer     True
# model            True
# condition        True
# cylinders        True
# fuel             True
# odometer         True
# title_status     True
# transmission     True
# vin              True
# drive            True
# size             True
# type             True
# paint_color      True
# image_url        True
# description      True
# county           True
# state           False
# lat              True
# long             True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1117
# manufacturer     20747
# model             6199
# condition       186806
# cylinders       166384
# fuel              2991
# odometer         75148
# title_status      1806
# transmission      2146
# vin             196652
# drive           122011
# size            295961
# type            117108
# paint_color     135247
# image_url           24
# description         27
# county          435849
# state                0
# lat               8235
# long              8235
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]  
#we do this to get the percentage of data that we're missing.
#We divide it by data.shape[0], as it gives the number of columns.
# Out:
# id              0.000000
# url             0.000000
# region          0.000000
# region_url      0.000000
# price           0.000000
# year            0.002563
# manufacturer    0.047601
# model           0.014223
# condition       0.428603
# cylinders       0.381747
# fuel            0.006862
# odometer        0.172418
# title_status    0.004144
# transmission    0.004924
# vin             0.451193
# drive           0.279939
# size            0.679045
# type            0.268689
# paint_color     0.310307
# image_url       0.000055
# description     0.000062
# county          1.000000
# state           0.000000
# lat             0.018894
# long            0.018894
# dtype: float64

# %%
data['type'].unique()
# Out:
# array([nan, 'sedan', 'pickup', 'convertible', 'truck', 'van', 'SUV',
#        'coupe', 'mini-van', 'hatchback', 'offroad', 'wagon', 'other',
#        'bus'], dtype=object)

# %%
data.type.value_counts()
# Out:
# SUV            80149
# sedan          79910
# pickup         40935
# truck          39517
# coupe          17417
# other          12869
# hatchback      12396
# van             9963
# wagon           9897
# convertible     8602
# mini-van        5906
# offroad          652
# bus              528
# Name: type, dtype: int64

# %%
data.type.value_counts()/data.type.notnull().sum()
#getting the percentage of not null values available for a particular data type.
# Out:
# SUV            0.251455
# sedan          0.250705
# pickup         0.128427
# truck          0.123978
# coupe          0.054643
# other          0.040374
# hatchback      0.038891
# van            0.031257
# wagon          0.031050
# convertible    0.026987
# mini-van       0.018529
# offroad        0.002046
# bus            0.001657
# Name: type, dtype: float64

# %%
data.year.hist()
# Out:
# <AxesSubplot:>

# %%
data.year.hist()
data.year.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data.type.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
