# %%
import pandas as pd

# %%
data=pd.read_csv('vehicles.csv')

# %%
data.head(10)
# Out:
#            id                                                url  \
# 0  7119256118  https://mohave.craigslist.org/ctd/d/lake-havas...
# 1  7120880186  https://oregoncoast.craigslist.org/cto/d/warre...
# 2  7115048251  https://greenville.craigslist.org/cto/d/sparta...
# 3  7119250502  https://mohave.craigslist.org/cto/d/lake-havas...
# 4  7120433904  https://maine.craigslist.org/ctd/d/searsport-t...
# 5  7120432569  https://maine.craigslist.org/ctd/d/bad-credit-...
# 6  7120431378  https://maine.craigslist.org/ctd/d/salem-nh-ma...
# 7  7120430837  https://maine.craigslist.org/cto/d/gardiner-20...
# 8  7120857037  https://oregoncoast.craigslist.org/ctd/d/portl...
# 9  7120844862  https://oregoncoast.craigslist.org/ctd/d/portl...
#
#                  region                          region_url  price    year  \
# 0         mohave county       https://mohave.craigslist.org   3495  2012.0
# 1          oregon coast  https://oregoncoast.craigslist.org  13750  2014.0
# ...

# %%
data.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
#to see all the numeric characteristics of a dataset

data.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.358490e+05  4.358490e+05  434732.000000  3.607010e+05     0.0
# mean   7.115954e+09  1.349127e+05    2009.866460  9.897590e+04     NaN
# std    4.590854e+06  1.690857e+07       9.312503  1.134990e+05     NaN
# min    7.096577e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.112450e+09  4.900000e+03    2007.000000  4.733300e+04     NaN
# 50%    7.117092e+09  9.995000e+03    2012.000000  9.118800e+04     NaN
# 75%    7.120090e+09  1.798900e+04    2015.000000  1.347360e+05     NaN
# max    7.121608e+09  3.647257e+09    2021.000000  1.000000e+07     NaN
#
#                  lat           long
# count  427614.000000  427614.000000
# mean       38.404163     -94.961170
# std         6.036915      18.058561
# min       -83.197100    -177.012000
# 25%        34.225700    -111.731000
# 50%        38.934800     -89.676700
# 75%        42.484500     -81.397300
# ...

# %%
data.shape
# Out:
# (435849, 25)

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull().any()
# Out:
# id              False
# url             False
# region          False
# region_url      False
# price           False
# year             True
# manufacturer     True
# model            True
# condition        True
# cylinders        True
# fuel             True
# odometer         True
# title_status     True
# transmission     True
# vin              True
# drive            True
# size             True
# type             True
# paint_color      True
# image_url        True
# description      True
# county           True
# state           False
# lat              True
# long             True
# dtype: bool

# %%
#we do this to check how many values are null in each of the types

data.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1117
# manufacturer     20747
# model             6199
# condition       186806
# cylinders       166384
# fuel              2991
# odometer         75148
# title_status      1806
# transmission      2146
# vin             196652
# drive           122011
# size            295961
# type            117108
# paint_color     135247
# image_url           24
# description         27
# county          435849
# state                0
# lat               8235
# long              8235
# dtype: int64

# %%
#to check the percentage of missing values---- null data by the total number of data columns
data.isnull().sum()/data.shape[0]
# Out:
# id              0.000000
# url             0.000000
# region          0.000000
# region_url      0.000000
# price           0.000000
# year            0.002563
# manufacturer    0.047601
# model           0.014223
# condition       0.428603
# cylinders       0.381747
# fuel            0.006862
# odometer        0.172418
# title_status    0.004144
# transmission    0.004924
# vin             0.451193
# drive           0.279939
# size            0.679045
# type            0.268689
# paint_color     0.310307
# image_url       0.000055
# description     0.000062
# county          1.000000
# state           0.000000
# lat             0.018894
# long            0.018894
# dtype: float64

# %%
#if we want to drop the total number of columns
#first we set a threshold value

thresh=data.shape[0]*0.6

# %%
thresh
# Out:
# 261509.4

# %%
#dropping columns where the threshold value for the percentage of missing values not less than 60%
data.dropna(thresh=thresh,axis=1)
# Out:
#                 id                                                url  \
# 0       7119256118  https://mohave.craigslist.org/ctd/d/lake-havas...
# 1       7120880186  https://oregoncoast.craigslist.org/cto/d/warre...
# 2       7115048251  https://greenville.craigslist.org/cto/d/sparta...
# 3       7119250502  https://mohave.craigslist.org/cto/d/lake-havas...
# 4       7120433904  https://maine.craigslist.org/ctd/d/searsport-t...
# ...            ...                                                ...
# 435844  7119262300  https://mohave.craigslist.org/cto/d/hualapai-2...
# 435845  7112219717  https://rapidcity.craigslist.org/cto/d/rapid-c...
# 435846  7120896708  https://oregoncoast.craigslist.org/cto/d/corne...
# 435847  7120885819  https://oregoncoast.craigslist.org/ctd/d/portl...
# 435848  7112215161  https://rapidcity.craigslist.org/ctd/d/rapid-c...
#
#                       region                          region_url  price  \
# ...

# %%
data.dropna(thresh=thresh,axis=1).shape
# Out:
# (435849, 21)

# %%
#dropping the row if the number of null values assciated with that row is lesser than 21.
data.dropna(thresh=21,axis=0)
# Out:
#                 id                                                url  \
# 1       7120880186  https://oregoncoast.craigslist.org/cto/d/warre...
# 3       7119250502  https://mohave.craigslist.org/cto/d/lake-havas...
# 6       7120431378  https://maine.craigslist.org/ctd/d/salem-nh-ma...
# 7       7120430837  https://maine.craigslist.org/cto/d/gardiner-20...
# 8       7120857037  https://oregoncoast.craigslist.org/ctd/d/portl...
# ...            ...                                                ...
# 435843  7115048966  https://greenville.craigslist.org/cto/d/greenv...
# 435844  7119262300  https://mohave.craigslist.org/cto/d/hualapai-2...
# 435845  7112219717  https://rapidcity.craigslist.org/cto/d/rapid-c...
# 435846  7120896708  https://oregoncoast.craigslist.org/cto/d/corne...
# 435848  7112215161  https://rapidcity.craigslist.org/ctd/d/rapid-c...
#
#                       region                          region_url  price  \
# ...

# %%
#dropping the row if the number of null values assciated with that row is lesser than 21.
data.dropna(thresh=21,axis=0).shape
# Out:
# (288147, 25)

# %%
#imputing the null values by inserting the median values
data.odometer.fillna(data.odometer.median())
# Out:
# 0          91188.0
# 1          76237.0
# 2         199000.0
# 3          54000.0
# 4          91188.0
#             ...
# 435844    282866.0
# 435845    194000.0
# 435846    130484.0
# 435847     93339.0
# 435848    148721.0
# Name: odometer, Length: 435849, dtype: float64

# %%
data.odometer.fillna(data.odometer.median()).isnull().any()
# Out:
# False

# %%
data.astype(str)
# Out:
#                 id                                                url  \
# 0       7119256118  https://mohave.craigslist.org/ctd/d/lake-havas...
# 1       7120880186  https://oregoncoast.craigslist.org/cto/d/warre...
# 2       7115048251  https://greenville.craigslist.org/cto/d/sparta...
# 3       7119250502  https://mohave.craigslist.org/cto/d/lake-havas...
# 4       7120433904  https://maine.craigslist.org/ctd/d/searsport-t...
# ...            ...                                                ...
# 435844  7119262300  https://mohave.craigslist.org/cto/d/hualapai-2...
# 435845  7112219717  https://rapidcity.craigslist.org/cto/d/rapid-c...
# 435846  7120896708  https://oregoncoast.craigslist.org/cto/d/corne...
# 435847  7120885819  https://oregoncoast.craigslist.org/ctd/d/portl...
# 435848  7112215161  https://rapidcity.craigslist.org/ctd/d/rapid-c...
#
#                       region                          region_url  price  \
# ...

# %%
#making the data type lower so as to better work with it!
data.description.astype(str)
# Out:
# 0         THIS 2012 JEEP PATRIOT IS A 4CYL. AC, STEREO, ...
# 1         Selling my 2014 BMW 328i with the following be...
# 2         01 DODGE CARAVAN,3.3 ENGINE,AUT TRANS,199000 M...
# 3         2004 Chevy Colorado LS, ONLY 54000 ORIGINAL MI...
# 4         CALL: 207.548.6500 TEXT: 207.407.5598  **WE FI...
#                                 ...
# 435844    2005 F150 XLT 5.4 TRITON NEEDS ENGINE, 2WD.  A...
# 435845    2002 Toyota Camry.  4-door, navy blue, good ti...
# 435846    I am selling my ford focus 2001 SE, 130 thousa...
# 435847    Simple Easy Car BuyingNo Games No Gimmicks    ...
# 435848    2010 Dodge Grand Caravan SXT     Offered by: L...
# Name: description, Length: 435849, dtype: object

# %%
data.description.astype(str).apply(lambda x:x.lower())
# Out:
# 0         this 2012 jeep patriot is a 4cyl. ac, stereo, ...
# 1         selling my 2014 bmw 328i with the following be...
# 2         01 dodge caravan,3.3 engine,aut trans,199000 m...
# 3         2004 chevy colorado ls, only 54000 original mi...
# 4         call: 207.548.6500 text: 207.407.5598  **we fi...
#                                 ...
# 435844    2005 f150 xlt 5.4 triton needs engine, 2wd.  a...
# 435845    2002 toyota camry.  4-door, navy blue, good ti...
# 435846    i am selling my ford focus 2001 se, 130 thousa...
# 435847    simple easy car buyingno games no gimmicks    ...
# 435848    2010 dodge grand caravan sxt     offered by: l...
# Name: description, Length: 435849, dtype: object

# %%
data.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
data.cylinders.dtype
# Out:
# dtype('O')

# %%
data.cylinders.value_counts()
# Out:
# 6 cylinders     95480
# 4 cylinders     86002
# 8 cylinders     82102
# 5 cylinders      2419
# 10 cylinders     1601
# other            1121
# 3 cylinders       533
# 12 cylinders      207
# Name: cylinders, dtype: int64

# %%
#getting rid of the any content with respect to the cylinders except the number of cylinders
data.cylinders=data.cylinders.apply(lambda x: str(x).lower().replace('cylinders'," ").strip())

# %%
data.cylinders
# Out:
# 0           4
# 1         nan
# 2           6
# 3           5
# 4         nan
#          ...
# 435844    nan
# 435845      6
# 435846      4
# 435847    nan
# 435848    nan
# Name: cylinders, Length: 435849, dtype: object

# %%
data.cylinders.value_counts()
# Out:
# nan      166384
# 6         95480
# 4         86002
# 8         82102
# 5          2419
# 10         1601
# other      1121
# 3           533
# 12          207
# Name: cylinders, dtype: int64

# %%
#to get the numeric value in these cases.
data.cylinders=pd.to_numeric(data.cylinders,errors='coerce')

# %%
data.cylinders.value_counts()
# Out:
# 6.0     95480
# 4.0     86002
# 8.0     82102
# 5.0      2419
# 10.0     1601
# 3.0       533
# 12.0      207
# Name: cylinders, dtype: int64

# %%
data.cylinders.fillna(data.cylinders.median(),inplace=True)

# %%
data.cylinders.value_counts()
# Out:
# 5.984453     167505
# 6.000000      95480
# 4.000000      86002
# 8.000000      82102
# 5.000000       2419
# 10.000000      1601
# 3.000000        533
# 12.000000       207
# Name: cylinders, dtype: int64

# %%
data.odometer.value_counts()
# Out:
# 0.0         2139
# 150000.0    1006
# 130000.0     979
# 140000.0     931
# 120000.0     893
#             ...
# 195439.0       1
# 97719.0        1
# 195436.0       1
# 48858.0        1
# 53663.0        1
# Name: odometer, Length: 108839, dtype: int64

# %%
data.odometer.value_counts().plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data.odometer.value_counts().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#this step is to remove the outliers from the data and to confine the structure to the required values
data_outliers=data[(data.price<data.price.quantile(0.995)) & (data.price>data.price.quantile(0.005))]

# %%
data_outliers.shape
# Out:
# (402966, 25)

# %%
data_outliers.boxplot('price')
# Out:
# <AxesSubplot:>

# %%
data_outliers.price.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
